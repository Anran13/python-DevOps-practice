# %%
var_ls = !ls -l
type(var_ls)
# Out:
# IPython.utils.text.SList

# %%
df = !df
type(df)
df.sort(3, nums=True)
# Out:
# ["'df' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC"]

# %%
ls = !ls -l /usr/bin
ls.grep("kill")
# Out:
# []

# %%
# %%writefile print_time.py
#!/usr/bin/env python
import datetime
print(datetime.datetime.now().time())
# Out:
# Overwriting print_time.py

# %%
# !python print_time.py
# Out:
# 12:00:38.002514
